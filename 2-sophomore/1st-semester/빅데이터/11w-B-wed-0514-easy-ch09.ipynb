# %% [markdown]
# # 09 데이터분석 프로젝트

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# PC에서 그림 설정
plt.rcParams.update({'figure.dpi': '100'})
plt.rcParams.update({'figure.figsize': [4, 2.5]})

# %%
# PC에서 한글 설정
plt.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
# 데이터프레임의 소수점 이하 n(2)자리 출력 설정
pd.set_option('display.precision', 2)

# %%
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'

# %%
# %pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading pyreadstat-1.2.8-cp312-cp312-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from pyreadstat) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from pandas>=1.2.0->pyreadstat) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadstat) (1.16.0)
# Downloading pyreadstat-1.2.8-cp312-cp312-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 372.9 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 372.9 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 372.9 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 372.9 kB/s eta 0:00:06
#    -------- ------------------------------- 0.5/2.4 MB 372.9 kB/s eta 0:00:06
#    ------------- -------------------------- 0.8/2.4 MB 299.6 kB/s eta 0:00:06
#    ----------------- ---------------------- 1.0/2.4 MB 387.2 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.0/2.4 MB 387.2 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.0/2.4 MB 387.2 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.0/2.4 MB 387.2 kB/s eta 0:00:04
#    --------------------- ------------------ 1.3/2.4 MB 360.8 kB/s eta 0:00:04
#    --------------------- ------------------ 1.3/2.4 MB 360.8 kB/s eta 0:00:04
#    --------------------- ------------------ 1.3/2.4 MB 360.8 kB/s eta 0:00:04
#    --------------------- ------------------ 1.3/2.4 MB 360.8 kB/s eta 0:00:04
#    --------------------- ------------------ 1.3/2.4 MB 360.8 kB/s eta 0:00:04
#    -------------------------- ------------- 1.6/2.4 MB 327.7 kB/s eta 0:00:03
#    -------------------------- ------------- 1.6/2.4 MB 327.7 kB/s eta 0:00:03
#    -------------------------- ------------- 1.6/2.4 MB 327.7 kB/s eta 0:00:03
#    -------------------------- ------------- 1.6/2.4 MB 327.7 kB/s eta 0:00:03
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ------------------------------ --------- 1.8/2.4 MB 335.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------- ----- 2.1/2.4 MB 293.6 kB/s eta 0:00:02
#    ---------------------------------------- 2.4/2.4 MB 268.6 kB/s eta 0:00:00
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.2.8
# Note: you may need to restart the kernel to use updated packages.

# %%
raw_welfare = pd.read_spss('data/Koweps_hpwc14_2019_beta2.sav')
raw_welfare
# Out:
#        h14_id  h14_ind  h14_sn  h14_merkey  h_new  h14_cobf  p14_wsc  p14_wsl  \
# 0         2.0      1.0     1.0    2.01e+04    0.0       NaN     0.29     0.29
# 1         3.0      1.0     1.0    3.01e+04    0.0       NaN     0.42     0.42
# 2         4.0      1.0     1.0    4.01e+04    0.0       NaN     0.27     0.27
# 3         6.0      1.0     1.0    6.01e+04    0.0       NaN     0.49     0.50
# 4         6.0      1.0     1.0    6.01e+04    0.0       NaN     1.02     1.02
# ...       ...      ...     ...         ...    ...       ...      ...      ...
# 14413  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14414  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14415  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14416  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
# 14417  9800.0      7.0     1.0    9.80e+07    1.0       NaN      NaN      NaN
#
#        p14_wgc  p14_wgl  ...  wc14_64  wc14_65  wc14_5aq4  wc14_5aq5  \
# 0      1307.76  1307.76  ...      NaN                 NaN        NaN
# 1      1882.57  1882.57  ...      NaN                 NaN        NaN
# 2      1189.69  1192.91  ...      NaN                 NaN        NaN
# 3      2219.63  2224.27  ...      1.0        .        2.0        4.0
# 4      4565.39  4565.39  ...      1.0        .        1.0        5.0
# ...        ...      ...  ...      ...      ...        ...        ...
# 14413      NaN      NaN  ...      NaN                 NaN        NaN
# 14414      NaN      NaN  ...      NaN                 NaN        NaN
# 14415      NaN      NaN  ...      NaN                 NaN        NaN
# 14416      NaN      NaN  ...      5.0        .        4.0        3.0
# 14417      NaN      NaN  ...      NaN                 NaN        NaN
#
#        wc14_5aq6  h14_pers_income1  h14_pers_income2  h14_pers_income3  \
# 0            NaN               NaN               NaN               NaN
# 1            NaN               NaN               NaN               NaN
# 2            NaN               NaN            1284.0               NaN
# 3            4.0            2304.0               NaN            1800.0
# 4            2.0               NaN               NaN               NaN
# ...          ...               ...               ...               ...
# 14413        NaN               NaN               NaN               NaN
# 14414        NaN               NaN               NaN               NaN
# 14415        NaN               NaN             208.0               NaN
# 14416        3.0               NaN            1200.0               NaN
# 14417        NaN               NaN               NaN               NaN
#
#        h14_pers_income4  h14_pers_income5
# 0                   0.0               NaN
# 1                   0.0               NaN
# 2                   0.0               NaN
# 3                   0.0               NaN
# 4                   0.0               NaN
# ...                 ...               ...
# 14413               0.0               NaN
# 14414               0.0               NaN
# 14415               0.0               NaN
# 14416               0.0               NaN
# 14417               0.0               NaN
#
# [14418 rows x 830 columns]

# %%
raw_welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Columns: 830 entries, h14_id to h14_pers_income5
# dtypes: float64(826), object(4)
# memory usage: 91.3+ MB

# %%
welfare = raw_welfare.copy()

# %%
welfare.shape
# Out:
# (14418, 830)

# %%
welfare = welfare.rename(columns= {'h14_g3': 'sex', 
                                   'h14_g4': 'birth',
                                   'h14_g10': 'marriage_type',
                                   'h14_g11': 'religion',
                                   'p1402_8aq1': 'income',
                                   'h14_eco9': 'code_job',
                                   'h14_reg7': 'code_region'})
welfare['sex']
# Out:
# 0        2.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        2.0
#         ...
# 14413    2.0
# 14414    2.0
# 14415    1.0
# 14416    2.0
# 14417    1.0
# Name: sex, Length: 14418, dtype: float64

# %%
welfare.sex.dtypes
# Out:
# dtype('float64')

# %%
welfare.sex.value_counts()
# Out:
# sex
# 2.0    7913
# 1.0    6505
# Name: count, dtype: int64

# %%
welfare.sex.isna().sum()
# Out:
# np.int64(0)

# %%
welfare['sex'] = np.where(welfare.sex == 1, 'male', 'female')
welfare['sex'].value_counts()
# Out:
# sex
# female    7913
# male      6505
# Name: count, dtype: int64

# %%
sns.countplot(welfare, x='sex', hue='sex');
