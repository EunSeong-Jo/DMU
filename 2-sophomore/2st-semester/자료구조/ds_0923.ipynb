# %% [markdown]
# import random

# %% [markdown]
# 지역, 전역변수

# %% [markdown]
# .isalnum()

# %%
def check(word):
    if len(word) > 8 and word.isalnum():
        print("로그인 성공")
    else:
        print("로그인 실패")

# %%
check("asdasd1234@")
# Out:
# 로그인 실패

# %% [markdown]
# 리스트 (집합과의 차이점)
#
# 선형리스트
#
# 추상 자료형(ADT)
#
# 데이터 : 같은 유형의 서로 비교할 수 있는 요소
#
# 배열 구조(구현, 접근) 이점, 연결된 구조(삽입/삭제, 크기 제한) 이점
# 구현, 항목 접근, 삽입/삭제, 크기 제한

# %% [markdown]
# 시간 복잡도
#
# append(e) : 복잡도 1
#
# o 나머지 항목이 삽입된 위치 뒤로 이동해야 해서 n
# insert(pos, e) : 복잡도 n
#
# pop(pos) : 복잡도 n

# %% [markdown]
# 배열(리스트, 튜플)

# %%
a = []
b = [1, 2, 3, 4, 5]
c = ['hi', 'hello']

print("a 리스트 길이 : ", len(a))
print("b : ", b)
print("c 두번째 값 : ", c[1])
# Out:
# a 리스트 길이 :  0
# b :  [1, 2, 3, 4, 5]
# c 두번째 값 :  hello

# %%
hap = 0

for i in range(len(b)):
    hap += b[i]
    
print("b 리스트 합 : ", hap)
# Out:
# b 리스트 합 :  15

# %%
import random

e = [random.randint(1, 10) for i in range(10)]

print(e)
# Out:
# [4, 6, 9, 8, 3, 1, 10, 2, 8, 4]

# %%
a.append(6)
a.append(7)
a
# Out:
# [6, 7]

# %%
a.pop(1)
a
# Out:
# [6]

# %%
a.insert(0, 100)
a
# Out:
# [100, 6]

# %%
b = [6, 7, 8, 9]

b.pop()
b.pop()
b.insert(0, 5)
b.insert(0, 4)

b
# Out:
# [4, 5, 6, 7]
