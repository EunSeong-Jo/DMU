# %% [markdown]
# # Chapter 2. 텍스트 전처리

# %% [markdown]
# ## 1. 토큰화(Tokenization)

# %% [markdown]
# #### NLTK (https://www.nltk.org/) 설치
#
# #### NLTK
# - 교육용으로 개발된 자연어 처리 및 문서 분석용 파이썬 패키지
# - WordNet 등 자연어 처리를 지원하는 다양한 라이브러리와 문서(말뭉치) 그리고 예제들을 제공

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('webtext')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     C:\Users\asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets_json is already up-to-date!
# True

# %% [markdown]
# ### 2.1 문장 토큰화(sentence tokenize)

# %%
para = "Hello everyone. It's good to see you. Let's start our text mining class!"

# %%
import nltk.data

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
print(tokenizer.tokenize(para))
# Out:
# ['Hello everyone.', "It's good to see you.", "Let's start our text mining class!"]

# %%
paragraph_french = """Je t'ai demandé si tu m'aimais bien, Tu m'a répondu non.
Je t'ai demandé si j'étais jolie, Tu m'a répondu non.
Je t'ai demandé si j'étai dans ton coeur, Tu m'a répondu non."""

tokenizer = nltk.data.load('tokenizers/punkt/french.pickle')
print(tokenizer.tokenize(paragraph_french))
# Out:
# ["Je t'ai demandé si tu m'aimais bien, Tu m'a répondu non.", "Je t'ai demandé si j'étais jolie, Tu m'a répondu non.", "Je t'ai demandé si j'étai dans ton coeur, Tu m'a répondu non."]

# %%
para_kor = "안녕하세요, 여러분. 만나서 반갑습니다. 이제 텍스트마이닝 클래스를 시작해봅시다!"

# %%
from nltk.tokenize import sent_tokenize

print(tokenizer.tokenize(para_kor))
# Out:
# ['안녕하세요, 여러분.', '만나서 반갑습니다.', '이제 텍스트마이닝 클래스를 시작해봅시다!']

# %% [markdown]
# ### 2.2 단어 토큰화 (word tokenize)

# %%
from nltk.tokenize import word_tokenize
print(word_tokenize(para))
# Out:
# ['Hello', 'everyone', '.', 'It', "'s", 'good', 'to', 'see', 'you', '.', 'Let', "'s", 'start', 'our', 'text', 'mining', 'class', '!']

# %%
from nltk.tokenize import WordPunctTokenizer
print(WordPunctTokenizer().tokenize(para))
# Out:
# ['Hello', 'everyone', '.', 'It', "'", 's', 'good', 'to', 'see', 'you', '.', 'Let', "'", 's', 'start', 'our', 'text', 'mining', 'class', '!']

# %%
print(word_tokenize(para_kor))
# Out:
# ['안녕하세요', ',', '여러분', '.', '만나서', '반갑습니다', '.', '이제', '텍스트마이닝', '클래스를', '시작해봅시다', '!']

# %% [markdown]
# ### 2.3 정규표현식을 이용한 토큰화

# %%
import re
re.findall("[abc]", "How are you, boy?")
# Out:
# ['a', 'b']

# %%
re.findall("[0123456789]", "3a7b5c9d")
# Out:
# ['3', '7', '5', '9']

# %%
re.findall("[_]+", "a_b, c__d, e___f")
# Out:
# ['_', '__', '___']

# %%
# [a-zA-Z0-9_]

re.findall(r"[\w]", "3a 7b_ '.^&5c9d")
# Out:
# ['3', 'a', '7', 'b', '_', '5', 'c', '9', 'd']

# %%
re.findall("[\w]+", "How are you, boy?")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\asus\AppData\Local\Temp\ipykernel_24344\2398766350.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("[\w]+", "How are you, boy?")
# ['How', 'are', 'you', 'boy']

# %%
re.findall("[o]{2,4}", "oh, hoow are yoooou, boooooooy?")
# Out:
# ['oo', 'oooo', 'oooo', 'ooo']

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r"[\w']+")
print(tokenizer.tokenize("Sorry, I can't go there."))
# Out:
# ['Sorry', 'I', "can't", 'go', 'there']

# %%
tokenizer = RegexpTokenizer(r"[\w]+")
print(tokenizer.tokenize("Sorry, I can't go there."))
# Out:
# ['Sorry', 'I', 'can', 't', 'go', 'there']

# %%
text1 = "Sorry, I can't go there."
tokenizer = RegexpTokenizer(r"[\w']{3,}")
print(tokenizer.tokenize(text1.lower()))
# Out:
# ['sorry', "can't", 'there']

# %% [markdown]
# ### 2.4 노이즈와 불용어 제거

# %%
from nltk.corpus import stopwords
english_stops = set(stopwords.words('english'))

text1 = "Sorry, I couldn't go to movie yesterday."

tokenizer = RegexpTokenizer(r"[\w']+")
tokens = tokenizer.tokenize(text1.lower())

result = [word for word in tokens if word not in english_stops]
print(result)
# Out:
# ['sorry', 'go', 'movie', 'yesterday']

# %%
print(english_stops)
# Out:
# {'be', "don't", 'so', 'being', 'wouldn', 'theirs', 'haven', 'off', 'own', "it'd", 'which', 'are', 'further', "you'd", 'me', 'hasn', 'how', 'she', 'am', "shouldn't", 'before', 'as', "i've", 'shan', 'some', 'were', "hasn't", "that'll", 'such', 'had', 'himself', 'yours', 'to', 'd', 're', 'very', "wasn't", 'above', 'ours', 'll', 'too', "they've", "they'd", 'but', 'his', 'didn', 'your', 'will', 'if', 'from', "we'd", 'all', 'shouldn', 'has', 'her', 'there', 'over', "it's", 've', 'weren', 'their', "they'll", 'few', 'herself', "i'd", 'then', "i'll", 'mustn', 'needn', 'should', 'doing', 'than', 'doesn', 'these', "we're", "won't", 'have', 'the', 'they', "mustn't", 'we', 's', 'down', "we've", 'yourselves', 'through', 'here', "she'll", 'that', "shan't", "you've", 'between', 'itself', 'other', 'won', "she's", 'did', 'isn', 'until', 'myself', 'he', 'ma', 'nor', 'while', 'more', 'can', 'm', 'both', 'do', 'because', 'for', 'its', 'themselves', 'once', "should've", "he'll", "couldn't", "he'd", 'under', 'don', 'is', "she'd", 'ourselves', 'him', 'was', "didn't", 'it', "haven't", "we'll", 'against', "needn't", "doesn't", "aren't", 'does', 'hadn', 'when', 'out', 'i', "he's", "it'll", 'mightn', 'in', 'with', 'what', "you'll", 'same', 'up', 'been', 'during', "mightn't", 'not', "you're", 'hers', 'why', 'at', 'y', 'who', 'those', "i'm", 'any', "isn't", 'them', "weren't", 'each', "they're", 'my', 'ain', "wouldn't", 'on', 'and', 'about', 'a', 'our', 't', 'into', 'aren', 'whom', 'having', 'yourself', 'after', 'this', 'where', "hadn't", 'most', 'an', 'again', 'now', 'just', 'no', 'o', 'you', 'by', 'below', 'couldn', 'wasn', 'or', 'of', 'only'}

# %%
my_stopword = ['i', 'go', 'to']
result = [word for word in tokens if word not in my_stopword]
print(result)
# Out:
# ['sorry', "couldn't", 'movie', 'yesterday']

# %% [markdown]
# # 2. 정규화(Normalization)
# ## 2.1 어간 추출(Stemming)

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
print(stemmer.stem('cooking'), stemmer.stem('cookery'), stemmer.stem('cookbooks'))
# Out:
# cook cookeri cookbook

# %%
from nltk.tokenize import word_tokenize

para = "Hello everyone. It's good to see you. Let's start our text mining class!"
tokens = word_tokenize(para) #토큰화 실행
print(tokens)
result = [stemmer.stem(token) for token in tokens] #모든 토큰에 대해 스테밍 실행
print(result)
# Out:
# ['Hello', 'everyone', '.', 'It', "'s", 'good', 'to', 'see', 'you', '.', 'Let', "'s", 'start', 'our', 'text', 'mining', 'class', '!']
# ['hello', 'everyon', '.', 'it', "'s", 'good', 'to', 'see', 'you', '.', 'let', "'s", 'start', 'our', 'text', 'mine', 'class', '!']

# %%
from nltk.stem import LancasterStemmer
stemmer = LancasterStemmer()
print(stemmer.stem('cooking'), stemmer.stem('cookery'), stemmer.stem('cookbooks'))
# Out:
# cook cookery cookbook

# %% [markdown]
# ## 2.2 표제어 추출(Lemmatization)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('cooking'))
print(lemmatizer.lemmatize('cooking', pos='v'))
print(lemmatizer.lemmatize('cookery'))
print(lemmatizer.lemmatize('cookbooks'))
# Out:
# cooking
# cook
# cookery
# cookbook

# %%
#comparison of lemmatizing and stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
print('stemming result:', stemmer.stem('believes'))
print('lemmatizing result:', lemmatizer.lemmatize('believes'))
print('lemmatizing result:', lemmatizer.lemmatize('believes', pos='v'))
# Out:
# stemming result: believ
# lemmatizing result: belief
# lemmatizing result: believe

# %% [markdown]
# # 3. 품사 태깅(Part-of-Speech Tagging)

# %% [markdown]
# ## 3.1 품사의 이해
# - 품사: 명사, 대명사, 수사, 조사, 동사, 형용사, 관형사, 부사, 감탄사와 같이 공통된 성질을 지닌 낱말끼리 모아 놓은 낱말의 갈래
# (네이버 지식백과 초등국어 개념
# 사전)
# - 주요 품사 태그 의미
# | 태그       | 의미           | 예              |
# | -------- | ------------ | -------------- |
# | **NNP**  | 고유명사 (단수)    | John, Korea    |
# | **NN**   | 일반명사 (단수)    | book, class    |
# | **PRP**  | 인칭대명사        | I, you, he     |
# | **PRP$** | 소유대명사        | my, your, our  |
# | **VB**   | 동사 원형        | go, start      |
# | **VBZ**  | 동사 3인칭 단수 현재 | goes, believes |
# | **JJ**   | 형용사          | good, big      |
# | **TO**   | to (부정사 표시)  | to go          |
# | **POS**  | 소유격 's       | John's         |
# | **.**    | 문장부호         | . ! ?          |

# %% [markdown]
# ## 3.2 NLTK를 이용한 품사 태깅

# %%
import nltk
from nltk.tokenize import word_tokenize

tokens = word_tokenize("Hello everyone. It's good to see you. Let's start our text mining class!")
print(nltk.pos_tag(tokens))
# Out:
# [('Hello', 'NNP'), ('everyone', 'NN'), ('.', '.'), ('It', 'PRP'), ("'s", 'VBZ'), ('good', 'JJ'), ('to', 'TO'), ('see', 'VB'), ('you', 'PRP'), ('.', '.'), ('Let', 'VB'), ("'s", 'POS'), ('start', 'VB'), ('our', 'PRP$'), ('text', 'NN'), ('mining', 'NN'), ('class', 'NN'), ('!', '.')]

# %%
nltk.help.upenn_tagset('NN')
# Out:
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...

# %%
my_tag_set = ['NN', 'VB', 'JJ']
my_words = [word for word, tag in nltk.pos_tag(tokens) if tag in my_tag_set]
print(my_words)
# Out:
# ['everyone', 'good', 'see', 'Let', 'start', 'text', 'mining', 'class']

# %%
words_with_tag = ['/'.join(item) for item in nltk.pos_tag(tokens)]
print(words_with_tag)
# Out:
# ['Hello/NNP', 'everyone/NN', './.', 'It/PRP', "'s/VBZ", 'good/JJ', 'to/TO', 'see/VB', 'you/PRP', './.', 'Let/VB', "'s/POS", 'start/VB', 'our/PRP$', 'text/NN', 'mining/NN', 'class/NN', '!/.']

# %% [markdown]
# ## 3.3 한글 형태소 분석과 품사 태깅

# %%
sentence = '''절망의 반대가 희망은 아니다.
어두운 밤하늘에 별이 빛나듯
희망은 절망 속에 싹트는 거지
만약에 우리가 희망함이 적다면
그 누가 세상을 비출어줄까.
정희성, 희망 공부'''

# %%
tokens = word_tokenize(sentence)
print(tokens)
print(nltk.pos_tag(tokens))
# Out:
# ['절망의', '반대가', '희망은', '아니다', '.', '어두운', '밤하늘에', '별이', '빛나듯', '희망은', '절망', '속에', '싹트는', '거지', '만약에', '우리가', '희망함이', '적다면', '그', '누가', '세상을', '비출어줄까', '.', '정희성', ',', '희망', '공부']
# [('절망의', 'JJ'), ('반대가', 'NNP'), ('희망은', 'NNP'), ('아니다', 'NNP'), ('.', '.'), ('어두운', 'VB'), ('밤하늘에', 'JJ'), ('별이', 'NNP'), ('빛나듯', 'NNP'), ('희망은', 'NNP'), ('절망', 'NNP'), ('속에', 'NNP'), ('싹트는', 'NNP'), ('거지', 'NNP'), ('만약에', 'NNP'), ('우리가', 'NNP'), ('희망함이', 'NNP'), ('적다면', 'NNP'), ('그', 'NNP'), ('누가', 'NNP'), ('세상을', 'NNP'), ('비출어줄까', 'NNP'), ('.', '.'), ('정희성', 'NN'), (',', ','), ('희망', 'NNP'), ('공부', 'NNP')]

# %% [markdown]
# ### KoNLPy 설치
#
# https://konlpy.org/ko/latest/install/

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from konlpy) (1.5.2)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from konlpy) (2.0.2)
# Requirement already satisfied: packaging in c:\users\asus\anaconda3\envs\dmu\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.1)

# %%
from konlpy.tag import Okt
t = Okt()

# %%
print('형태소:', t.morphs(sentence))
print()
print('명사:', t.nouns(sentence))
print()
print('품사 태깅 결과:', t.pos(sentence))
# Out:
# 형태소: ['절망', '의', '반대', '가', '희망', '은', '아니다', '.', '\n', '어', '두운', '밤하늘', '에', '별', '이', '빛나듯', '\n', '희망', '은', '절망', '속', '에', '싹트는', '거지', '\n', '만약', '에', '우리', '가', '희망', '함', '이', '적다면', '\n', '그', '누가', '세상', '을', '비출어줄까', '.', '\n', '정희성', ',', '희망', '공부']
#
# 명사: ['절망', '반대', '희망', '어', '두운', '밤하늘', '별', '희망', '절망', '속', '거지', '만약', '우리', '희망', '함', '그', '누가', '세상', '정희성', '희망', '공부']
#
# 품사 태깅 결과: [('절망', 'Noun'), ('의', 'Josa'), ('반대', 'Noun'), ('가', 'Josa'), ('희망', 'Noun'), ('은', 'Josa'), ('아니다', 'Adjective'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('어', 'Noun'), ('두운', 'Noun'), ('밤하늘', 'Noun'), ('에', 'Josa'), ('별', 'Noun'), ('이', 'Josa'), ('빛나듯', 'Verb'), ('\n', 'Foreign'), ('희망', 'Noun'), ('은', 'Josa'), ('절망', 'Noun'), ('속', 'Noun'), ('에', 'Josa'), ('싹트는', 'Verb'), ('거지', 'Noun'), ('\n', 'Foreign'), ('만약', 'Noun'), ('에', 'Josa'), ('우리', 'Noun'), ('가', 'Josa'), ('희망', 'Noun'), ('함', 'Noun'), ('이', 'Josa'), ('적다면', 'Verb'), ('\n', 'Foreign'), ('그', 'Noun'), ('누가', 'Noun'), ('세상', 'Noun'), ('을', 'Josa'), ('비출어줄까', 'Verb'), ('.', 'Punctuation'), ('\n', 'Foreign'), ('정희성', 'Noun'), (',', 'Punctuation'), ('희망', 'Noun'), ('공부', 'Noun')]
