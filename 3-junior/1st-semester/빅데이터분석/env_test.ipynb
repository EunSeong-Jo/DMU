# %%
import os
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

API_KEY = os.getenv("DATA_KR_API_KEY")
print(API_KEY)
# Out:
# 4523765f5cae67a2be8cac0d059bea95fbde42a159cab8c028548809ec4416bb
