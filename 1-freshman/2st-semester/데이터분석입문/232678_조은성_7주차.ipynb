# %% [markdown]
# ### 1교시

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
x = [1,2,3,4,5]
y = [6,7,8,9,10]

plt.plot(x, y ,marker='o', linestyle='-', label='hdamekfmld')

plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('dddd')
plt.legend()
plt.show()

# %%
# 시험

plt.plot([1, 2, 3, 4], [10, 20, 30, 40], color='r', linestyle='--',
marker='d', linewidth=3, label='thick line')

plt.plot([1, 2, 3, 4], [40, 30, 20, 10], 'b', ls=':', marker='^', lw=0.5,
label='thin line')

plt.title(' marker linewidth linestyle')
plt.xlabel('X (axis)')
plt.ylabel('Y (axis)')
plt.legend()
plt.show()

# %%
x = np.random.randint(-10, 10, 10)

print(x)
print(x > 0)
print(x[x > 0])
# Out:
# [ 7  8 -1  5  6 -6  4  9  7 -2]
# [ True  True False  True  True False  True  True  True False]
# [7 8 5 6 4 9 7]

# %%
np.random.seed(42)

N = 80
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (20* np.random.rand(N)) ** 2


plt.scatter(x, y, s=area, c=colors, alpha=0.7)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)

mask1 = abs(x) > 50
mask2 = abs(y) > 50

x = x[mask1 + mask2]
y = y[mask1 + mask2]

plt.scatter(x, y, c = x, cmap = 'jet', alpha = 0.4)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(-100, 100, 1000)
y = np.random.randint(-100, 100, 1000)

mask1 = abs(x) > 50
mask2 = abs(y) > 50

x = x[mask1 * mask2]
y = y[mask1 * mask2]

plt.scatter(x, y, c = x, cmap = 'jet', alpha = 0.4)
plt.colorbar()
plt.show()

# %%
plt.bar(['red','green','blue'], [10,30,29])
plt.show()

# %%
c = ['red','green','blue']

plt.bar(c, [12, 30, 21], color = c, alpha = 0.5)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.hist([1, 1, 1, 2, 2, 3, 4, 5, 6, 6, 6, 6], rwidth=.98, bins=[.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5])
plt.xticks(range(1, 7))

plt.show()

# %%
dice = np.random.choice(range(1,7), 100, p = [0.15, 0.25, 0.3, 0.1, 0.1, 0.1])
plt.figure(figsize=(5, 3), dpi=200)

plt.hist(dice, rwidth=.98, bins=np.arange(.5, 7))
plt.xticks(range(1, 7))

# plt.savefig('주사위.png')
plt.show()

# %%
plt.figure(figsize=(9,4))

plt.subplot(2, 3, 1)
plt.plot([1, 2, 3])
plt.subplot(2, 3, 5)
plt.subplot(2, 3, 6)
plt.plot([5,4,3])

plt.show()

# %%
plt.figure(figsize=(9,4))

plt.subplot(2, 3, 1)
ax = plt.subplot(2, 3, 5)

plt.subplot(2, 3, 6)
ax.plot([20, 5, 10])

plt.show()

# %%
plt.figure(figsize=(9,4))

fig, axs = plt.subplots(2, 4)
plt.show()

# %%
fig, axs = plt.subplots(2, 4)
fig.set_size_inches(9, 4)

axs[0,1].plot([5, 1, 3])
axs[1,0].plot([3, 3, 1])

plt.plot([10, 5, 20])
plt.show()

# %%
fig = plt.figure()

fig.add_subplot(331).set_title('331')
fig.add_subplot(332).set_title('332')
fig.add_subplot(333).set_title('333')
fig.add_subplot(334).set_title('334')

fig.subplots_adjust(wspace=0.2, hspace=0.7)
plt.show()

# %%
fig = plt.figure(figsize=(7, 5))

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
fig = plt.figure(figsize=(7, 5))

ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax2.plot([1, 2, 3])
ax3.plot([3, 2, 1])
ax4.plot([1, 3, 2])

plt.show()

# %% [markdown]
# ### 2교시

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6))

axes[0].plot([1, 2, 3], [1, 4, 9])
axes[1].plot([1, 2, 3], [1, 2, 3])

plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6))
fig.set_size_inches(10, 4)

axes[0].plot([1, 2, 3], [1, 4, 9])
axes[1].plot([1, 2, 3], [1, 2, 3])

plt.show()

# %%
fig1 = plt.figure()

ax1 = fig1.add_subplot(2, 2, 1)
ax1.plot([1, 2, 3], [1, 2, 3])

ax2 = fig1.add_subplot(2, 2, 4)
ax2.plot([1, 2, 3], [1, 4, 9])

fig2 = plt.figure()
ax3 = fig2.add_subplot(1, 1, 1)
ax3.plot([1, 2, 3], [2, 3, 5])

plt.show()

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, constrained_layout=True) 

for i in range(2):
    for j in range(2):
        axs[i, j].plot([1, 2, 3], [1, 4, 9])

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(3, 3)

f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('gs1')

f3_ax2 = fig3.add_subplot(gs[1, :-1])
f3_ax2.set_title('gs2')

f3_ax3 = fig3.add_subplot(gs[1:, -1])
f3_ax3.set_title('gs3')
# Out:
# Text(0.5, 1.0, 'gs3')

# %%
fig3 = plt.figure(constrained_layout=True)
gs = fig3.add_gridspec(3, 3)

f3_ax1 = fig3.add_subplot(gs[0, :])
f3_ax1.set_title('gs1')

f3_ax2 = fig3.add_subplot(gs[1, :-1])
f3_ax2.set_title('gs2')

f3_ax3 = fig3.add_subplot(gs[1:, -1])
f3_ax3.set_title('gs3')

x = np.linspace(0, 2 * np.pi, 100)
f3_ax1.plot(x, np.sin(x))

# %%
gs = gridspec.GridSpec(8, 39)
ax1 = plt.subplot(gs[:6, :35])
ax2 = plt.subplot(gs[6:, :])

# %%
gs = gridspec.GridSpec(8, 39)
ax1 = plt.subplot(gs[:6, :35])
ax2 = plt.subplot(gs[6:, :])

x = np.linspace(0, 2*np.pi, 100)
ax2.plot(x, np.cos(x), color='blue')
ax2.plot(x, np.sin(x), color='green')
ax2.plot(x, np.cos(x)*np.sin(x), color='red')

# %%
np.random.seed(42)
np.set_printoptions(precision=2)

data1 = np.random.rand(6, 35)
data2 = np.random.rand(2, 29)

print(data1)
print()
print(data2)
# Out:
# [[0.37 0.95 0.73 0.6  0.16 0.16 0.06 0.87 0.6  0.71 0.02 0.97 0.83 0.21
#   0.18 0.18 0.3  0.52 0.43 0.29 0.61 0.14 0.29 0.37 0.46 0.79 0.2  0.51
#   0.59 0.05 0.61 0.17 0.07 0.95 0.97]
#  [0.81 0.3  0.1  0.68 0.44 0.12 0.5  0.03 0.91 0.26 0.66 0.31 0.52 0.55
#   0.18 0.97 0.78 0.94 0.89 0.6  0.92 0.09 0.2  0.05 0.33 0.39 0.27 0.83
#   0.36 0.28 0.54 0.14 0.8  0.07 0.99]
#  [0.77 0.2  0.01 0.82 0.71 0.73 0.77 0.07 0.36 0.12 0.86 0.62 0.33 0.06
#   0.31 0.33 0.73 0.64 0.89 0.47 0.12 0.71 0.76 0.56 0.77 0.49 0.52 0.43
#   0.03 0.11 0.03 0.64 0.31 0.51 0.91]
#  [0.25 0.41 0.76 0.23 0.08 0.29 0.16 0.93 0.81 0.63 0.87 0.8  0.19 0.89
#   0.54 0.81 0.9  0.32 0.11 0.23 0.43 0.82 0.86 0.01 0.51 0.42 0.22 0.12
#   0.34 0.94 0.32 0.52 0.7  0.36 0.97]
#  [0.96 0.25 0.5  0.3  0.28 0.04 0.61 0.5  0.05 0.28 0.91 0.24 0.14 0.49
#   0.99 0.24 0.67 0.76 0.24 0.73 0.37 0.63 0.63 0.54 0.09 0.84 0.32 0.19
#   0.04 0.59 0.68 0.02 0.51 0.23 0.65]
# ...

# %%
gs = gridspec.GridSpec(8, 39)
ax1 = plt.subplot(gs[:6, :35])
ax2 = plt.subplot(gs[6:, :])

np.random.seed(42)
data1 = np.random.rand(6, 35)
data2 = np.random.rand(2, 29)

ax1.imshow(data1, cmap='Purples')
ax2.imshow(data2)

plt.show()

# %%
fig4= plt.figure(constrained_layout=True)
spec4 = fig4.add_gridspec(ncols=2, nrows=2)


anno_opts = dict(xy=(0.5, 0.5), xycoords='axes fraction', va='center', ha='center')


f4_ax1 = fig4.add_subplot(spec4[0, 0])
f4_ax1. annotate( 'GridSpec[0. 0]', **anno_opts)
fig4.add_subplot(spec4[0, 1]).annotate('GridSpec[0, 1:]', **anno_opts)
fig4.add_subplot(spec4[1, 0]).annotate('GridSpec[1:, 0]', **anno_opts)
fig4.add_subplot(spec4[1, 1]).annotate('GridSpec[1:, 1:]', **anno_opts)
# Out:
# Text(0.5, 0.5, 'GridSpec[1:, 1:]')

# %%
fig5 = plt.figure(constrained_layout=True)

widths = [2, 3, 1.5]
heights = [1, 3, 2]

spec5 = fig5.add_gridspec(ncols=3, nrows=3, width_ratios=widths, height_ratios=heights)

for row in range(3):
    for col in range(3):
        ax = fig5.add_subplot(spec5[row, col])
        label = f'w = {widths[col]}, h = {heights[row]}'
        ax.annotate(label, (0.1, 0.5), xycoords='axes fraction', va='center')

# %%
fig5 = plt.figure(constrained_layout=True)

widths = [4, 6, 3]
heights = [1, 3, 2]

gs_kw = dict(width_ratios=widths, height_ratios=heights)

fig6, f6_axes = plt.subplots(ncols=3, nrows=3, constrained_layout=True, gridspec_kw=gs_kw)

for r, row in enumerate(f6_axes):
    for c, ax in enumerate(row):
        label = f'w = {widths[c]}, h = {heights[r]}'
        ax.annotate(label, (0.1, 0.5), xycoords='axes fraction', va='center')

# %%
fig7, f7_axs = plt.subplots(ncols=3, nrows=3)

gs = f7_axs[1, 2].get_gridspec()
print(gs)

gs = f7_axs[0, 2].get_gridspec()
print(gs)

f7_axs[1, -1].remove()
f7_axs[2, -1].remove()

axbig = fig7.add_subplot(gs[1:, -1])

axbig.annotate('abbbaidne', (0.1, 0.5), xycoords='axes fraction', va='center')

fig7.tight_layout()
# Out:
# GridSpec(3, 3)
# GridSpec(3, 3)

# %%
fig8 = plt.figure(constrained_layout=False)
gs1 = fig8.add_gridspec(nrows=3, ncols=3, left=0.05, right=0.45, hspace=0.3, wspace=0.7)

f8_ax1 = fig8.add_subplot(gs1[:-1, :])
f8_ax2 = fig8.add_subplot(gs1[-1, :-1])
f8_ax3 = fig8.add_subplot(gs1[-1, -1])

# %%
fig9 = plt.figure(constrained_layout=False)

gs1 = fig9.add_gridspec(nrows=3, ncols=3, left=0.05, right=0.45, wspace=0.5)

f9_ax1 = fig9.add_subplot(gs1[:-1, :])
f9_ax1.annotate('gs1[:-1, :]', (0.1, 0.5), xycoords='axes fraction', va='center')

f9_ax2 = fig9.add_subplot(gs1[-1, :-1])
f9_ax2.annotate('gs1[-1, :-1]', (0.1, 0.5), xycoords='axes fraction', va='center')

f9_ax1 = fig9.add_subplot(gs1[-1, -1])
f9_ax1.annotate('gs1[-1, -1]', (0.1, 0.5), xycoords='axes fraction', va='center')


gs2 = fig9.add_gridspec(nrows=3, ncols=3, left=0.55, right=0.9, hspace=0.5)

f9_ax4 = fig9.add_subplot(gs2[:, :-1])
f9_ax4.annotate('gs1[:-1, :]', (0.1, 0.5), xycoords='axes fraction', va='center')

f9_ax5 = fig9.add_subplot(gs2[:-1, -1])
f9_ax5.annotate('gs1[-1, :-1]', (0.1, 0.5), xycoords='axes fraction', va='center')

f9_ax6 = fig9.add_subplot(gs2[-1, -1])
f9_ax6.annotate('gs1[-1, -1]', (0.1, 0.5), xycoords='axes fraction', va='center')

plt.subplots_adjust(hspace=0.5, wspace=0.7)

# %%
fig10 = plt.figure(constrained_layout=True)
gs10 = fig10.add_gridspec(1, 2)

gs11 = gs10[0].subgridspec(2, 3)
gs12 = gs10[1].subgridspec(3, 2)

for a in range(2):
    for b in range(3):
        fig10.add_subplot(gs11[a, b])
        fig10.add_subplot(gs12[b, a])

# %%
fig11 = plt.figure(figsize=(8, 8), constrained_layout=False)
outer_grid = fig11.add_gridspec(4, 4, wspace=0, hspace=0)

for a in range(4):
    for b in range(4):
        inner_grid = outer_grid[a, b].subgridspec(3, 3, wspace=0, hspace=0)
        axs = inner_grid.subplots()

        for(c, d), ax in np.ndenumerate(axs):
            s1, s2 = f'{a},{b}', f'{c}, {d}'
            ax.text(0.1, 0.3, s1, fontsize=7)
            ax.text(0.1, 0.6, s2, fontsize=7)
            ax.set(xticks=[], yticks=[])

plt.show()

# %%
def squiggle_xy(a, b, c, d, i=np.arange(0.0, 2*np.pi, 0.05)):
    return np.sin(i*a) * np.cos(i*b), np.sin(i*c) * np.cos(i*d)

fig = plt.figure(figsize=(4, 4))

plt.plot(*squiggle_xy(1, 2, 1, 3))
plt.show()

# %%
def squiggle_xy(a, b, c, d, i=np.arange(0.0, 2*np.pi, 0.05)):
    return np.sin(i*a)*np.cos(i*b), np.sin(i*c)*np.cos(i*d)


fig11 = plt.figure(figsize=(8, 8), constrained_layout=False)
outer_grid = fig11.add_gridspec(4, 4, wspace=0, hspace=0)


for a in range(4):
    for b in range(4):
        inner_grid = outer_grid[a, b].subgridspec(3, 3, wspace=0, hspace=0)
        axs = inner_grid.subplots()


        for(c, d), ax in np.ndenumerate(axs):
            ax.plot(*squiggle_xy(a + 1, b + 1, c + 1, d + 1))
            ax.set(xticks=[], yticks=[])


# show only the outside spines
for ax in fig11.get_axes ():
    ss = ax.get_subplotspec()
    ax.spines.top.set_visible(ss.is_first_row())
    ax.spines.bottom.set_visible(ss.is_last_row())
    ax.spines.left.set_visible(ss.is_first_col())
    ax.spines.right.set_visible(ss.is_last_col())

plt.show()
